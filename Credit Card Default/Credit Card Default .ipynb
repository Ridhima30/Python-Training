# %%
import pandas as pd
import numpy as np

# %%
ccd=pd.read_excel("default_of_credit_card_clients_0.xlsx")

# %%
type(ccd)
# Out:
# pandas.core.frame.DataFrame

# %%
ccd.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2      0      0
# 1   2     120000    2          2         2   26      0      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57      0      0      0      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
#we see there are no null values in the data
ccd.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
df=ccd.copy()

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2      0
# 1          2     120000    2          2         2   26      0      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57      0      0      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43      0      0      0
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1      0      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df["EDUCATION"].value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 5      280
# 4      123
# 6       51
# 0       14
# Name: EDUCATION, dtype: int64

# %%
#replacing values 0,5,6 with others(val=4)
df["EDUCATION"].replace(0, 4, inplace=True)
df["EDUCATION"].replace(5, 4, inplace=True)
df["EDUCATION"].replace(6, 4, inplace=True)

# %%
df["EDUCATION"].value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 4      468
# Name: EDUCATION, dtype: int64

# %%
df["SEX"].value_counts()
# Out:
# 2    18112
# 1    11888
# Name: SEX, dtype: int64

# %%
df["MARRIAGE"].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64

# %%
df["MARRIAGE"].replace(0, 3, inplace=True)

# %%
df["MARRIAGE"].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      377
# Name: MARRIAGE, dtype: int64

# %%
df["AGE"].value_counts()
# Out:
# 29    1605
# 27    1477
# 28    1409
# 30    1395
# 26    1256
# 31    1217
# 25    1186
# 34    1162
# 32    1158
# 33    1146
# 24    1127
# 35    1113
# 36    1108
# 37    1041
# 39     954
# 38     944
# 23     931
# 40     870
# 41     824
# 42     794
# 44     700
# 43     670
# 45     617
# 46     570
# 22     560
# 47     501
# 48     466
# 49     452
# 50     411
# 51     340
# 53     325
# 52     304
# 54     247
# 55     209
# 56     178
# 58     122
# 57     122
# 59      83
# 60      67
# 21      67
# 61      56
# 62      44
# 63      31
# 64      31
# 66      25
# 65      24
# 67      16
# 69      15
# 70      10
# 68       5
# 73       4
# 71       3
# 72       3
# 75       3
# 74       1
# 79       1
# Name: AGE, dtype: int64

# %%
df["PAY_0"].value_counts()
# Out:
# 0    23182
# 1     3688
# 2     2667
# 3      322
# 4       76
# 5       26
# 8       19
# 6       11
# 7        9
# Name: PAY_0, dtype: int64

# %%
# calculate outstanding amount for each month
df["OUT_1"]=df["BILL_AMT1"]-df["PAY_AMT1"]
df["OUT_2"]=df["BILL_AMT2"]-df["PAY_AMT2"]
df["OUT_3"]=df["BILL_AMT3"]-df["PAY_AMT3"]
df["OUT_4"]=df["BILL_AMT4"]-df["PAY_AMT4"]
df["OUT_5"]=df["BILL_AMT5"]-df["PAY_AMT5"]
df["OUT_6"]=df["BILL_AMT6"]-df["PAY_AMT6"]

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2      0
# 1          2     120000    2          2         2   26      0      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57      0      0      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43      0      0      0
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1      0      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df["Total OUT"]=df["OUT_1"]+df["OUT_2"]+df["OUT_3"]+df["OUT_4"]+df["OUT_5"]+df["OUT_6"]

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2      0
# 1          2     120000    2          2         2   26      0      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57      0      0      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43      0      0      0
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1      0      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
import seaborn as sns

# %%
#majority people lie in the age of 27-38
df["AGE"].hist()

# %%
sns.distplot(df["AGE"])

# %%
#there are a lot of outliers 
sns.boxplot(df["AGE"])

# %%
sns.boxplot(df["Total OUT"])

# %%
df["Total OUT"].describe()
# Out:
# count    3.000000e+04
# mean     2.382103e+05
# std      3.631651e+05
# min     -2.671514e+06
# 25%      4.520750e+03
# 50%      1.019230e+05
# 75%      3.057178e+05
# max      4.116080e+06
# Name: Total OUT, dtype: float64

# %%
df["AGE"].describe()
# Out:
# count    30000.000000
# mean        35.485500
# std          9.217904
# min         21.000000
# 25%         28.000000
# 50%         34.000000
# 75%         41.000000
# max         79.000000
# Name: AGE, dtype: float64

# %%
#relation between age and outstanding amounts
sns.lineplot(x = df['AGE'], y = df['Total OUT'], hue=df["default payment next month"])

# %%
#relation between education and outstanding amounts
sns.lineplot(x = df['EDUCATION'], y = df['Total OUT'], hue=df["default payment next month"])

# %%
#relation between marriage and outstanding amounts
sns.lineplot(x = df['MARRIAGE'], y = df['Total OUT'], hue=df["default payment next month"])

# %%
#relation between credit limit and outstanding amounts
sns.lineplot(x = df['LIMIT_BAL'], y = df['Total OUT'], hue=df["default payment next month"])

# %%
#OUTSTANDING AMOUNT VS DEFAULT BEHAVIOUR
sns.lineplot(x = df['default payment next month'], y = df['Total OUT'])

# %%
df.pivot_table(values=["Total OUT"], index=["MARRIAGE","SEX", "EDUCATION"], aggfunc=np.mean)
# Out:
#                             Total OUT
# MARRIAGE SEX EDUCATION
# 1        1   1          273182.627219
#              2          266895.956962
#              3          258011.019084
#              4          356351.902439
#          2   1          204223.735728
#              2          253522.063730
#              3          215947.469388
#              4          325311.888158
# 2        1   1          248640.108621
#              2          234919.241156
#              3          205658.861298
#              4          258031.151163
#          2   1          201694.694684
#              2          257617.090441
#              3          215182.686700
#              4          272274.078571
# 3        1   1          310217.161290
#              2          150301.968750
#              3          149826.354167
#              4           98321.000000
#          2   1            5214.478261
#              2          186754.807692
#              3          134723.979798
# ...

# %%
df.pivot_table(values=["BILL_AMT1","BILL_AMT2","BILL_AMT3","BILL_AMT4","BILL_AMT5","BILL_AMT6"], index=["MARRIAGE","SEX", "EDUCATION"], aggfunc=np.mean)
# Out:
#                             BILL_AMT1     BILL_AMT2     BILL_AMT3  \
# MARRIAGE SEX EDUCATION
# 1        1   1           60196.886391  56841.282840  55180.526036
#              2           56465.218143  54125.950211  51740.359494
#              3           55910.685115  52443.879771  50041.388359
#              4           91748.634146  83300.146341  73564.182927
#          2   1           44337.774114  43080.453248  43686.190453
#              2           54135.562835  51873.166145  48833.044723
#              3           45768.902372  44013.479316  42716.723111
#              4           69816.315789  66717.059211  66329.618421
# 2        1   1           54064.399164  52811.889480  49665.841246
#              2           50926.275850  48499.191837  45166.255782
#              3           45000.682327  43400.732662  40058.414989
#              4           62726.430233  58686.151163  55405.116279
#          2   1           43004.106082  41783.862787  40540.301964
# ...

# %%
sns.distplot(df["Total OUT"])

# %%
sns.distplot(df["LIMIT_BAL"])

# %%
import matplotlib.pyplot as plt

# %%
df2=df.head(25)

# %%
plt.plot(df2["ID"],df2["OUT_1"], label="Month 1")
plt.plot(df2["ID"],df2["OUT_2"], label="Month 2")
plt.plot(df2["ID"],df2["OUT_3"], label="Month 3")
plt.plot(df2["ID"],df2["OUT_4"], label="Month 4")
plt.plot(df2["ID"],df2["OUT_5"], label="Month 5")
plt.plot(df2["ID"],df2["OUT_6"], label="Month 6")
plt.xlabel("Customers")
plt.ylabel("Outstanding Amount")
plt.legend()
plt.show()

# %%
ccd
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2      0
# 1          2     120000    2          2         2   26      0      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57      0      0      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43      0      0      0
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1      0      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X=ccd.iloc[:, :-1]
Y=ccd.iloc[:,-1]

# %%
X
Y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: default payment next month, Length: 30000, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn import neighbors
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier

# %%
model=SVC(kernel='linear',gamma=10, C=1)

# %%
model.fit(X_train, Y_train)
